# %% [markdown]
# # 변수 - 자료형의 값을 저장하는 공간

# %%
a=1 #숫자형

# %%
b='python' #문자형

# %%
c=[1,2,3] #리스트

# %%
id(c) #메모리 주소 확인
# Out:
# 1855019721152

# %%
c
# Out:
# [1, 2, 3]

# %%
id(a)
# Out:
# 140715576501160

# %% [markdown]
# ## 2. 리스트를 복사하고자 할 때

# %%
a=[1,2,3]
b=a
b
# Out:
# [1, 2, 3]

# %%
id(a)
# Out:
# 1855025726656

# %%
id(b)
# Out:
# 1855025726656

# %%
a is b #변수 a, 변수 b는 같은 객체를 가르킴
# Out:
# True

# %%
#a에 있는 값 변경
a[0]=4
a
# Out:
# [4, 2, 3]

# %%
b #a만 변경했는데 b도 변경됨
# Out:
# [4, 2, 3]

# %% [markdown]
# ### b 변수에 a 변수를 복사할 때 값만 복사하고 다른 주소를 가르키도록 만드는 방법

# %%
#:

# %%
a
# Out:
# [-1, 2, 3]

# %%
id(a)
# Out:
# 1855026308992

# %%
id(b)
# Out:
# 1855026326784

# %%
a[-1]=-3
a
# Out:
# [1, 2, -3]

# %%
b
# Out:
# [1, 2, 3]

# %%
#copy

# %%
from copy import copy
a=[1,2,3]
b=copy(a)

# %%
b is a
# Out:
# False

# %%
a[1]=0
a
# Out:
# [1, 0, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
#copy() 함수 이용하기

# %%
a=[1,2,3]
b=a.copy()

# %%
id(a)
# Out:
# 1855026469376

# %%
id(b)
# Out:
# 1855019504320

# %%
a is b
# Out:
# False

# %%
a[0]=-1
a
# Out:
# [-1, 2, 3]

# %%
b
# Out:
# [1, 2, 3]

# %% [markdown]
# ## 3. 변수를 만드는 여러가지 방법

# %%
#튜플로 변수 만들기
a,b=('python','life')

# %%
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
(a,b)='python','life'

# %%
print(a,b)
# Out:
# python life

# %%
a,b='python','life'

# %%
print(a,b)
# Out:
# python life

# %%
# 리스트로 변수 만들기
[a,b]=['pyont','life']

# %%
a
# Out:
# 'pyont'

# %%
b
# Out:
# 'life'

# %%
# 여러 변수를 같은 값 대입

# %%
a=b='python'
print(a,b)
# Out:
# python python

# %%
id(a)
# Out:
# 1854917962048

# %%
id(b)
# Out:
# 1854917962048

# %%
# 두 변수의 값 바꾸기(파이썬만 가능)

# %%
a=3
b=5
a,b=b,a
a
# Out:
# 5

# %%
b
# Out:
# 3
