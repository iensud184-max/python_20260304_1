# %% [markdown]
# # 집합(set)

# %% [markdown]
# ## 1. 집합 자료형은 어떻게 만들까?

# %%
s1=set([1,2,2,3,3,4])
s1
# Out:
# {1, 2, 3, 4}

# %%
s2=set('hello')
s2
# Out:
# {'e', 'h', 'l', 'o'}

# %% [markdown]
# ## 2. 집합 자료형의 특징
# - 중복을 허용하지 않는다.
# - 순서가 없다.

# %%
s1=set([1,2,2,3]) 
s1
# Out:
# {1, 2, 3}

# %%
type(s1)
# Out:
# set

# %%
l1=list(s1)

# %%
l1
# Out:
# [1, 2, 3]

# %%
s1[0] #순서가 없음, 즉 인덱싱과 슬라이싱 불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s1[0] #순서가 없음, 즉 인덱싱과 슬라이싱 불가
#
# TypeError: 'set' object is not subscriptable

# %%
l1[0]
# Out:
# 1

# %%
t1=tuple(s1)
t1
# Out:
# (1, 2, 3)

# %%
t1[0]
# Out:
# 1

# %%
t1[-1]
# Out:
# 3

# %%
t1[:2]
# Out:
# (1, 2)

# %% [markdown]
# ## 3. 교집합, 합집합, 차집합 구하기

# %%
s1=set([1,2,3,4,5,6])
s2=set([4,5,6,7,8,9])

# %%
# 교집합(&) 구하기
s1 & s2
# Out:
# {4, 5, 6}

# %%
s1 .intersection (s2)
# Out:
# {4, 5, 6}

# %%
#합집합(|)
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1 .union (s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
# 차집합 (-)
s1-s2
# Out:
# {1, 2, 3}

# %%
s1 .difference (s2)
# Out:
# {1, 2, 3}

# %%
s2 .difference (s1)
# Out:
# {7, 8, 9}

# %% [markdown]
# ## 4. 집합 자료형 관련 함수

# %% [markdown]
# ### add() : 값 1개 푸가하기

# %%
s1=set([1,2,3])
s1
# Out:
# {1, 2, 3}

# %%
s1.add(4)
s1
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### update() : 값 여러개 추가하기

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1. update([5,6,])
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ### remove() : 특정 값 제거하기

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.remove(3)
s1
# Out:
# {1, 2, 4, 5, 6}

# %%
s1.remove([4,5])
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 s1.remove([4,5])
#       2 s1
#
# TypeError: unhashable type: 'list'
